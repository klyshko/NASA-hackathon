# %% [markdown]
# ## The notebook is working with the Global Landslide Catalog dataset
# ### Here we explore the dataset and finding the columns that are not important and can be dropped off

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io

import warnings

# %%
data = pd.read_csv('rows.csv')

# %%
data.columns
# Out:
# Index(['the_geom', 'OBJECTID', 'id', 'date_', 'time_', 'country', 'nearest_pl',
#        'hazard_typ', 'landslide_', 'trigger', 'storm_name', 'fatalities',
#        'injuries', 'source_nam', 'source_lin', 'location_a', 'landslide1',
#        'photos_lin', 'cat_src', 'cat_id', 'countrynam', 'near', 'distance',
#        'adminname1', 'adminname2', 'population', 'countrycod', 'continentc',
#        'key_', 'version', 'user_id', 'tstamp', 'changeset_', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6788 entries, 0 to 6787
# Data columns (total 27 columns):
# id            6788 non-null int64
# date_         6784 non-null object
# country       6180 non-null object
# nearest_pl    6724 non-null object
# hazard_typ    6788 non-null object
# landslide_    6788 non-null object
# trigger       6788 non-null object
# fatalities    6788 non-null int64
# injuries      6788 non-null int64
# source_nam    2495 non-null object
# source_lin    6283 non-null object
# location_a    6788 non-null object
# landslide1    6786 non-null object
# photos_lin    289 non-null object
# cat_src       6787 non-null object
# cat_id        6788 non-null int64
# countrynam    6788 non-null object
# near          6787 non-null object
# distance      6788 non-null float64
# adminname1    6717 non-null object
# adminname2    3794 non-null object
# population    6788 non-null int64
# countrycod    0 non-null float64
# continentc    4617 non-null object
# key_          6786 non-null object
# latitude      6788 non-null float64
# longitude     6788 non-null float64
# dtypes: float64(4), int64(5), object(18)
# memory usage: 1.4+ MB

# %%
data = data.drop(columns=['time_', 'storm_name', 'OBJECTID', 'the_geom'])

# %%
data = data.drop(columns=['tstamp','changeset_','user_id', 'version'])

# %%
data.hazard_typ = 'Landslide'

# %%
data.hazard_typ.unique()
# Out:
# array(['Landslide'], dtype=object)

# %% [markdown]
# ### Cleaned  the data from useless columns and fixed `Landslide` typo

# %%
data[['country', 'nearest_pl','location_a', 'cat_src', 'cat_id', 'countrynam', 'near', 'adminname1', 'adminname2']]
# Out:
#               country                                         nearest_pl  \
# 0       United States  Grove Street from Anderson Avenue to Hine Hill...
# 1           Indonesia                                      Borneo, Muara
# 2                 NaN                                  Ocean Falls, B.C.
# 3              Canada  road to Holberg, 3 km from hwy 19, Vancouver I...
# 4                 NaN                                 Rennell Sound Road
# 5              Canada  main road in Port Alice and Neucel Pulp Mill, ...
# 6       United States  Wrangell-St. Elias National Preserve, Chisana, Ak
# 7              Canada    Fort McNeill, Vancover Island, British Colombia
# 8              Canada                                 Kingcome Inlet, ON
# 9           Indonesia  four villages in Lempake Jaya, North Samarinda...
# 10          Indonesia  Petir village, Darmaga sub district, Bogor dis...
# 11             Canada  Teslin, Yukon territory ( between Junction 37 ...
# 12          Indonesia         Majo Kampung BarijeÂ , North Sumatra, Nias
# 13               Peru                                          Quellouno
# 14      United States  Mt La Perouse Glacier Bay National Park and Pr...
# 15             Canada                               Daniel'S Harbour, Nl
# 16             Canada                               Daniel'S Harbour, Nl
# 17             Canada        Western Newfoundland town, Daniel's Harbour
# 18    Myanmar (Burma)  Hmawzizar Jade Mine in Phakant, Pha-Kant in Ka...
# 19                NaN                                            Hpakant
# 20    Myanmar (Burma)      road between Hsaidaung(?) and Hpakant, Kachin
# 21            Myanmar                                     Hpakan, Kachin
# 22             Canada                                   Redditt, Ontario
# 23    Myanmar (Burma)            Sakhan Thit village in Kyun Su township
# 24                NaN                                        Mount Haast
# 25                NaN                                          Mt. Haast
# 26                NaN                                           Mt Haast
# 27                NaN                                           Mt Haast
# 28        New Zealand                    Auraki-Mount Cook National Park
# 29                NaN          Ball Ridge, 1km southwest of Caroline Hut
# ...               ...                                                ...
# 6758    United States                         Bella Meade, Nashville, TN
# 6759         Thailand                                      Kathu, Phuket
# 6760    United States  608 Biorka St Tongass National Forest, Sitka, ...
# 6761             Peru                                            Chosica
# 6762      Philippines           Jasaan town in Misamis Oriental province
# 6763    United States  Port Angeles, Olympic Peninsula, Washington State
# 6764      Philippines  Sitio Lapuan in Barangay Lanao in Don Marcelio...
# 6765             Peru                                    Zurite district
# 6766             Peru                        Zurite district, near Cusco
# 6767      Philippines  Barangay Kingking, Pantukan town, Composta Valley
# 6768            Kenya                             Kangema, Murang'a West
# 6769           Israel      Highway 40 between Mitzpeh Rimon and Machtesh
# 6770    United States                                           Kent, WA
# 6771      Philippines                  City Camp Lagoon; Itogon, Benguet
# 6772            Japan  Joshinetsu Expressway in Komoro, Nagano Prefec...
# 6773             Peru          Aricapampa towns of La Libertad province.
# 6774    United States          US 421, north of Hyden, Leslie County, KY
# 6775    United States                   444 6th St Lake Oswego, OR 97034
# 6776      Philippines                   Valencia City, Bukidnon province
# 6777      Philippines         Lumbayao villages, Valencia City, Bukidnon
# 6778         Cameroon     Abuh, Fundong Subdivision, North West Province
# 6779  Solomon Islands                                                NaN
# 6780           Greece  Zacharo municipality and other regions (Rhodop...
# 6781        Guatemala                          AndrÃ©s Semetabaj, Solola
# 6782      Philippines                                 Salvador, Mindanao
# 6783      El Salvador                                              Ataco
# 6784    United States  Westbound Lanes of Interstate 90 (between exit...
# 6785    United States                                        Anaheim, CA
# 6786    United States  North Bend Waste Water Treatment North Bend, W...
# 6787         Columbia                                     Palermo, Huila
#
#                location_a cat_src  cat_id       countrynam  \
# 0       Known_within_1_km     glc    3177    United States
# 1                 Unknown     glc     490        Indonesia
# 2        Known_within_1km     glc    6760           Canada
# 3       Known_within_1_km     glc    2494           Canada
# 4       Known_within_15km     glc    6415           Canada
# 5       Known_within_5_km     glc    2493           Canada
# 6       Known_within_5_km    test    5194    United States
# 7       Known_within_5_km     glc    4066           Canada
# 8      Known_within_25_km     glc    2505           Canada
# 9      Known_within_25_km     glc     945        Indonesia
# 10     Known_within_50_km     glc     853        Indonesia
# 11     Known_within_15_km     glc    4397           Canada
# 12     Known_within_50_km     glc    4073        Indonesia
# 13    Known_within_200_km     glc    5751             Peru
# 14       Known_within_1km     glc    5874    United States
# 15      Known_within_5_km     glc    5624           Canada
# 16      Known_within_5_km     glc    5671           Canada
# 17      Known_within_1_km     glc      62           Canada
# 18     Known_within_25_km     glc     678  Myanmar [Burma]
# 19       Known_within_5km     glc    6656  Myanmar [Burma]
# 20     Known_within_25_km     glc    2084  Myanmar [Burma]
# 21      Known_within_5_km     glc    6124  Myanmar [Burma]
# 22     Known_within_15_km     glc    6108           Canada
# 23                Unknown    test    3622  Myanmar [Burma]
# 24         Exact_Location     glc    6642      New Zealand
# 25         Exact_Location     glc    6639      New Zealand
# 26         Exact_Location     glc    6641      New Zealand
# 27         Exact_Location     glc    6640      New Zealand
# 28     Known_within_10_km     glc     423      New Zealand
# 29       Known_within_1km     glc    6643      New Zealand
# ...                   ...     ...     ...              ...
# 6758   Known_within_10_km     glc    1850    United States
# 6759   Known_within_10_km     glc    3946         Thailand
# 6760    Known_within_5_km     glc    5788    United States
# 6761    Known_within_5_km     glc    1361             Peru
# 6762    Known_within_5_km     glc    1326      Philippines
# 6763    Known_within_1_km     glc    1317    United States
# 6764   Known_within_25_km     glc    1419      Philippines
# 6765    Known_within_5_km     glc    1476             Peru
# 6766    Known_within_1_km     glc    1495             Peru
# 6767   Known_within_25_km     glc     464      Philippines
# 6768    Known_within_5_km     glc    1276            Kenya
# 6769    Known_within_5_km     glc    1368           Israel
# 6770    Known_within_5_km     glc    3734    United States
# 6771   Known_within_25_km     glc     538      Philippines
# 6772    Known_within_5_km     glc     432            Japan
# 6773    Known_within_5_km     glc    1005             Peru
# 6774    Known_within_5_km     glc    1815    United States
# 6775    Known_within_1_km     glc    5854    United States
# 6776   Known_within_50_km     glc    3725      Philippines
# 6777   Known_within_10_km     glc    3726      Philippines
# 6778   Known_within_15_km     glc     283         Cameroon
# 6779    Known_within_5_km     glc    1427  Solomon Islands
# 6780   Known_within_10_km     glc     358           Greece
# 6781    Known_within_5_km     glc    2353        Guatemala
# 6782   Known_within_25_km     glc     461      Philippines
# 6783    Known_within_5_km     glc     230      El Salvador
# 6784    Known_within_5_km     glc    3755    United States
# 6785    Known_within_5_km     glc    2553    United States
# 6786    Known_within_5_km     glc    5916    United States
# 6787    Known_within_5_km     glc    5959         Colombia
#
#                        near                        adminname1  \
# 0               New Milford                       Connecticut
# 1                Longnawang                  North Kalimantan
# 2                   Kitimat                  British Columbia
# 3            Campbell River                  British Columbia
# 4             Prince Rupert                  British Columbia
# 5            Campbell River                  British Columbia
# 6                       Tok                            Alaska
# 7            Campbell River                  British Columbia
# 8            Campbell River                  British Columbia
# 9                 Sungaiboh                  North Kalimantan
# 10               Sungairaya                   West Kalimantan
# 11              Watson Lake                             Yukon
# 12               Pulo Batal                              Aceh
# 13           Quebrada Honda                             Cusco
# 14                   Haines                            Alaska
# 15                Deer Lake         Newfoundland and Labrador
# 16                Deer Lake         Newfoundland and Labrador
# 17                Deer Lake         Newfoundland and Labrador
# 18                Myitkyina                            Kachin
# 19                Myitkyina                            Kachin
# 20                Myitkyina                            Kachin
# 21                Myitkyina                            Kachin
# 22                Ear Falls                           Ontario
# 23                  Mae Sai                              Shan
# 24           Pleasant Point                        West Coast
# 25           Pleasant Point                        Canterbury
# 26           Pleasant Point                        West Coast
# 27           Pleasant Point                        Canterbury
# 28           Pleasant Point                        Canterbury
# 29           Pleasant Point                        Canterbury
# ...                     ...                               ...
# 6758            Belle Meade                         Tennessee
# 6759                  Kathu                            Phuket
# 6760                  Sitka                            Alaska
# 6761                Chosica                              Lima
# 6762                 Jasaan                 Northern Mindanao
# 6763           Port Angeles                        Washington
# 6764             Talagutong                             Davao
# 6765                 Zurite                             Cusco
# 6766                 Zurite                             Cusco
# 6767               Pantukan                             Davao
# 6768                Kangema                          Murang'A
# 6769           Mitzpe Ramon                 Southern District
# 6770                   Kent                        Washington
# 6771                 Itogon  Cordillera Administrative Region
# 6772                 Komoro                            Nagano
# 6773             Aricapampa                       La Libertad
# 6774                  Hyden                          Kentucky
# 6775            Lake Oswego                            Oregon
# 6776               Valencia                 Northern Mindanao
# 6777               Valencia                 Northern Mindanao
# 6778                Fundong               North-West Province
# 6779                Honiara                       Guadalcanal
# 6780               ZachÃ¡ro                       West Greece
# 6781  San AndrÃ©s Semetabaj                           SololÃ¡
# 6782               Salvador                      Soccsksargen
# 6783   ConcepciÃ³n de Ataco                       AhuachapÃ¡n
# 6784               Sheridan                           Wyoming
# 6785                Anaheim                        California
# 6786             North Bend                        Washington
# 6787                Palermo                             Huila
#
#                   adminname2
# 0          Litchfield County
# 1                        NaN
# 2                        obe
# 3                        NaN
# 4                        obe
# 5                        NaN
# 6                        obe
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13        Provincia de Calca
# 14            Haines Borough
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       obe
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       obe
# 24                       obe
# 25                       obe
# 26                       obe
# 27                       obe
# 28           Timaru District
# 29                       obe
# ...                      ...
# 6758         Davidson County
# 6759                     NaN
# 6760  Sitka City and Borough
# 6761                    Lima
# 6762        Misamis Oriental
# 6763          Clallam County
# 6764           Davao del Sur
# 6765       Provincia de Anta
# 6766       Provincia de Anta
# 6767                   Davao
# 6768                     NaN
# 6769                     NaN
# 6770             King County
# 6771                 Benguet
# 6772                     NaN
# 6773         Sanchez Carrion
# 6774           Leslie County
# 6775        Clackamas County
# 6776                Bukidnon
# 6777                Bukidnon
# 6778                     NaN
# 6779                     NaN
# 6780         Ilia Prefecture
# 6781                     NaN
# 6782                PH.12.34
# 6783                     NaN
# 6784         Sheridan County
# 6785           Orange County
# 6786             King County
# 6787                     NaN
#
# [6788 rows x 9 columns]

# %%
data.columns
# Out:
# Index(['id', 'date_', 'country', 'nearest_pl', 'hazard_typ', 'landslide_',
#        'trigger', 'fatalities', 'injuries', 'source_nam', 'source_lin',
#        'location_a', 'landslide1', 'photos_lin', 'cat_src', 'cat_id',
#        'countrynam', 'near', 'distance', 'adminname1', 'adminname2',
#        'population', 'countrycod', 'continentc', 'key_', 'latitude',
#        'longitude'],
#       dtype='object')

# %% [markdown]
# ### Here I want to determine the source of news based on the website provided

# %% [markdown]
# The idea is to create a function that takes a large url (e.g. http://www.newstimes.com/local/article/New-Milford-Kent-hit-hard-by-flooding-1046004.php) as an argument and returns the name or description of the source, such as `The New York Times`

# %% [markdown]
# #### Examples of URLs

# %%
for ws in data.source_lin[:10]:
    print(ws)
# Out:
# http://www.newstimes.com/local/article/New-Milford-Kent-hit-hard-by-flooding-1046004.php
# http://www.brunei-online.com/bb/tue/apr1h10.htm
# http://globalnews.ca/news/1818913/mudslide-splits-town-of-ocean-falls-in-half/
# http://www.theprovince.com/news/State+emergency+Port+Hardy/3581434/story.html
# http://www.cftktv.com/News/Story.aspx?ID=2164634
# http://www.vancouversun.com/news/Rains+cause+mudslide+power+outages+Vancouver+Island/3579800/story.html
# http://www.alaskadispatch.com/article/20130914/summer-heatwave-may-have-triggered-landslide-lonely-alaska-glacier
# http://www.globaltvbc.com/mudslide+closes+section+of+highway+19+near+port+mcneill/6442530653/story.html
# http://www.newswire.ca/en/releases/archive/September2010/27/c5513.html
# http://www.thejakartaglobe.com/news/article/4210.html

# %% [markdown]
# ### The approach is to parse the url and extract the domain name, then make a YAHOO search request with a keyword that is equals to a domain name of the website and extract the title of the 1st result of the search engine

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import time

def get_title(word):
    url = "http://search.yahoo.com/search?p="
    r = requests.get(url + word) 
    time.sleep(0.2)
    soup = BeautifulSoup(r.text, 'lxml')
    links = soup.find_all(attrs={"class": "title"})
    if len(links) > 0:
        if links[0].text == 'Including results for ':
            return links[1].text
        else:
            return links[0].text

def get_website(url):

    parsed_uri = urlparse(url)
    result = '{uri.netloc}'.format(uri=parsed_uri)
    #result = '{uri.scheme}://{uri.netloc}/'.format(uri=parsed_uri)
    return result

# %% [markdown]
# ### Checking an approach... printing out the source name and the website name

# %%
for index, row in data.iterrows():
    if pd.isnull(row['source_nam']) and not pd.isnull(row['source_lin']):
        print(get_title(get_website(row['source_lin'])), get_website(row['source_lin']))
        row['source_nam'] = get_title(get_website(row['source_lin']))
# Out:
# NewsTimes: Greater Danbury Area News, Fairfield County News ... www.newstimes.com
# Brunei Online Store - 1 Stop E-Commerce Store in Brunei .... www.brunei-online.com
# The Province www.theprovince.com
# Vancouver Sun www.vancouversun.com
# Global BC www.globaltvbc.com
# Newswire www.newswire.ca
# The Jakarta Globe www.thejakartaglobe.com
# The Jakarta Post www.thejakartapost.com
# KTVA www.ktva.com
# news.com.au www.news.com.au
# Reuters www.reuters.com
# The Philippine Star www.philstar.com
# GNS Science www.gns.cri.nz
# GNS Science www.gns.cri.nz
# ThreeNow www.tv3.co.nz
# Radio Fiji Two - FM 105.2 - Suva - Listen Online www.radiofiji.com.fj
# The Jakarta Post www.thejakartapost.com
# SIKKIM.COM isikkim.com
# The Star thestar.com.my
# Zee News zeenews.india.com
# AlterNet www.alertnet.org
# Radio Fiji Two - FM 105.2 - Suva - Listen Online www.radiofiji.com.fj
# News18.com: CNN-News18 Breaking News India, Latest News ... ibnlive.in.com
# HimVani - The Voice of Himachal www.himvani.com
# The Advertiser | Latest Adelaide and South Australia News ... www.adelaidenow.com.au
# The Borneo Post www.theborneopost.com
# The Prince George Citizen www.princegeorgecitizen.com
# Fiji Times www.fijitimes.com
# The Borneo Post www.theborneopost.com
# www-secure.ifrc.org www-secure.ifrc.org
# Cody Enterprise www.codyenterprise.com
# YouTube www.youtube.com
# 中國電視新聞網|網絡電視|衛星電視 - 新唐人中文電視台在線 english.ntdtv.com
# When to use the volatile keyword in C# | InfoWorld www.cnkeyword.info
# AlterNet www.alertnet.org
# Sliding Thought Blog | Washington’s Landslide Blog | Page 5 slidingthought.wordpress.com
# Indian Express www.indianexpress.com
# Vancouver Sun www.vancouversun.com
# Al Jazeera English english.aljazeera.net
# Utah News from the Daily Herald www.heraldextra.com
# CBC.ca www.cbc.ca
# ReliefWeb www.reliefweb.int
# 新华网 让新闻离你更近 - xinhuanet.com news.xinhuanet.com
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-3b7ea5f99511> in <module>()
#       2     if pd.isnull(row['source_nam']) and not pd.isnull(row['source_lin']):
#       3         print(get_title(get_website(row['source_lin'])), get_website(row['source_lin']))
# ----> 4         row['source_nam'] = get_title(get_website(row['source_lin']))
#
# <ipython-input-114-862554a16da8> in get_title(word)
#      10     soup = BeautifulSoup(r.text, 'lxml')
#      11     links = soup.find_all(attrs={"class": "title"})
# ---> 12     if links[0].text == 'Including results for ':
#      13         return links[1].text
#      14     else:
#
# IndexError: list index out of range

# %% [markdown]
# ### Checking the approach on the other part of the data

# %%
for index, row in data.iterrows():
    if pd.isnull(row['source_nam']) and not pd.isnull(row['source_lin']):
        print(get_title(get_website(row['source_lin'])), get_website(row['source_lin']))
        row['source_nam'] = get_title(get_website(row['source_lin']))
# Out:
# NewsTimes: Greater Danbury Area News, Fairfield County News ... www.newstimes.com
# Brunei Online Store - 1 Stop E-Commerce Store in Brunei .... www.brunei-online.com
# The Province www.theprovince.com
# Vancouver Sun www.vancouversun.com
# Global BC www.globaltvbc.com
# Newswire www.newswire.ca
# The Jakarta Globe www.thejakartaglobe.com
# The Jakarta Post www.thejakartapost.com
# KTVA www.ktva.com
# news.com.au www.news.com.au
# Reuters www.reuters.com
# The Philippine Star www.philstar.com
# GNS Science www.gns.cri.nz
# GNS Science www.gns.cri.nz
# ThreeNow www.tv3.co.nz
# Radio Fiji Two - FM 105.2 - Suva - Listen Online www.radiofiji.com.fj
# The Jakarta Post www.thejakartapost.com
# SIKKIM.COM isikkim.com
# The Star thestar.com.my
# Zee News zeenews.india.com
# AlterNet www.alertnet.org
# Radio Fiji Two - FM 105.2 - Suva - Listen Online www.radiofiji.com.fj
# News18.com: CNN-News18 Breaking News India, Latest News ... ibnlive.in.com
# HimVani - The Voice of Himachal www.himvani.com
# The Advertiser | Latest Adelaide and South Australia News ... www.adelaidenow.com.au
# The Borneo Post www.theborneopost.com
# The Prince George Citizen www.princegeorgecitizen.com
# Fiji Times www.fijitimes.com
# The Borneo Post www.theborneopost.com
# www-secure.ifrc.org www-secure.ifrc.org
# Cody Enterprise www.codyenterprise.com
# YouTube www.youtube.com
# 中國電視新聞網|網絡電視|衛星電視 - 新唐人中文電視台在線 english.ntdtv.com
# When to use the volatile keyword in C# | InfoWorld www.cnkeyword.info
# AlterNet www.alertnet.org
# Sliding Thought Blog | Washington’s Landslide Blog | Page 5 slidingthought.wordpress.com
# Indian Express www.indianexpress.com
# Vancouver Sun www.vancouversun.com
# Al Jazeera English english.aljazeera.net
# Utah News from the Daily Herald www.heraldextra.com
# CBC.ca www.cbc.ca
# ReliefWeb www.reliefweb.int
# 新华网 让新闻离你更近 - xinhuanet.com news.xinhuanet.com
# The Times of India timesofindia.indiatimes.com
# Warrnambool Standard www.standard.net.au
# Daily Mercury www.dailymercury.com.au
# AllAfrica.com allafrica.com
# nst.com.my - New Straits Times www.nst.com.my
# Indian Express www.indianexpress.com
# The Times of India timesofindia.indiatimes.com
# The Borneo Post www.theborneopost.com
# Newshub www.3news.co.nz
# Berita Terkini Indonesia - ANTARA News www.antara.co.id
# The Himalayan Times www.thehimalayantimes.com
# The Times of India timesofindia.indiatimes.com
# 新华网 让新闻离你更近 - xinhuanet.com news.xinhuanet.com
# Nepalnews : Nepal's first online news portal www.nepalnews.com
# The Himalayan Times www.thehimalayantimes.com
# ReliefWeb www.reliefweb.int
# HeraldNet.com - Everett and Snohomish County news from The Herald www.heraldnet.com
# Iceland Review www.icelandreview.com
# Daily Nation www.nation.co.ke
# Latino | Fox News latino.foxnews.com
# Pique Newsmagazine www.piquenewsmagazine.com
# Hindustan Times www.hindustantimes.com
# KanglaOnline – Information Gateway kanglaonline.com
# Monsters and Critics www.monstersandcritics.com
# Express Tribune tribune.com.pk
# Monsters and Critics www.monstersandcritics.com
# Fijivillage | Fiji's Latest News and Sports website www.fijivillage.com
# saigon-gpdaily.com.vn - Giấy Phép Daily Saigon www.saigon-gpdaily.com.vn
# The Daily Star – Leading English Daily among Bangladesh ... www.thedailystar.net
# HimVani - The Voice of Himachal www.himvani.com
# Fiji Times www.fijitimes.com
# Stuff.co.nz www.stuff.co.nz
# Berita Terkini Indonesia - ANTARA News www.antara.co.id
# Boise News, Weather, Sports, Breaking News | KBOI www.kboi2.com
# The Himalayan Times www.thehimalayantimes.com
# Statesman Journal www.statesmanjournal.com
# I Love Chile | Chilean Travel and News Media ilovechile.cl
# The Himalayan Times www.thehimalayantimes.com
# Blogger - Saturday, 14 May 2011 khmernz.blogspot.com
# The Daily Star – Leading English Daily among Bangladesh ... www.thedailystar.net
# ekantipur www.kantipuronline.com
# The Wenatchee World wenatcheeworld.com
# The Register-Guard: Local News, Politics, Entertainment ... www.registerguard.com
# My Republica www.myrepublica.com
# ekantipur www.kantipuronline.com
# Nepalnews : Nepal's first online news portal www.nepalnews.com
# Taiwan News Online － Breaking News, Politics, Environment ... www.etaiwannews.com
# Armidale Express www.armidaleexpress.com.au
# Trinidad Express Newspapers www.trinidadexpress.com
# Bloomberg Businessweek www.businessweek.com
# Stuff.co.nz www.stuff.co.nz
# BBC - Home www.bbc.co.uk
# The Himalayan Times www.thehimalayantimes.com
# The Umpqua Post www.theumpquapost.com
# Trinidad and Tobago Newsday www.newsday.co.tt
# Trinidad and Tobago Newsday www.newsday.co.tt
# The Age www.theage.com.au
# Monsters and Critics www.monstersandcritics.com
# The Himalayan Times www.thehimalayantimes.com
# 新华网 让新闻离你更近 - xinhuanet.com news.xinhuanet.com
# The Himalayan Times www.thehimalayantimes.com
# ekantipur www.kantipuronline.com
# ReliefWeb www.reliefweb.int
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-133-3b7ea5f99511> in <module>()
#       2     if pd.isnull(row['source_nam']) and not pd.isnull(row['source_lin']):
#       3         print(get_title(get_website(row['source_lin'])), get_website(row['source_lin']))
# ----> 4         row['source_nam'] = get_title(get_website(row['source_lin']))
#
# <ipython-input-118-b5820245c01e> in get_title(word)
#       7     url = "http://search.yahoo.com/search?p="
#       8     r = requests.get(url + word)
# ----> 9     time.sleep(0.2)
#      10     soup = BeautifulSoup(r.text, 'lxml')
#      11     links = soup.find_all(attrs={"class": "title"})
#
# KeyboardInterrupt:

# %% [markdown]
# #### Comment:
# After 500 requests to YAHOO service their server bans my ip due to "too many requests"

# %% [markdown]
# ## Summary:
# The approach works well and can be scaled to other data sets
